# %% [markdown]
# ## Notebook for Binary System Analysis
# YES

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import sys 
import os

import seaborn as sns

# %%
print(np.pi * 2 * 1.01 )
# Out:
# 6.346017160251382

# %%
colnames=['T','X','Y','Z','VX', 'VY', 'VZ']
colnames_ex = ['T','X','Y','Z','VX', 'VY', 'VZ', 'T', 'U']
file11name = "../.vscode/build/Debug/output/test2/body1.csv"
file12name = "../.vscode/build/Debug/output/test2/body2.csv"
data11 = pd.read_csv(file11name,skiprows=1, sep='\t',names=colnames,header=None)
data12 = pd.read_csv(file12name,skiprows=1, sep='\t',names=colnames,header=None)
print(data11)
# Out:
#            T             X             Y  Z            VX            VY  VZ
# 0     0.0000  0.000000e+00  0.000000e+00  0  0.000000e+00  0.000000e+00   0
# 1     0.0001  5.922630e-13  0.000000e+00  0  1.184530e-08  0.000000e+00   0
# 2     0.0002  2.369050e-12  3.713490e-16  0  2.369050e-08  7.426980e-12   0
# 3     0.0003  5.330370e-12  1.856750e-15  0  3.553580e-08  2.228090e-11   0
# 4     0.0004  9.476210e-12  5.198890e-15  0  4.738100e-08  4.456190e-11   0
# ...      ...           ...           ... ..           ...           ...  ..
# 9995  0.9995  1.418770e-08  1.880400e-05  0  3.634920e-08 -5.190210e-08   0
# 9996  0.9996  1.419190e-08  1.880390e-05  0  4.821080e-08 -5.186560e-08   0
# 9997  0.9997  1.419730e-08  1.880390e-05  0  6.007230e-08 -5.182180e-08   0
# 9998  0.9998  1.420390e-08  1.880390e-05  0  7.193380e-08 -5.177040e-08   0
# 9999  0.9999  1.421170e-08  1.880390e-05  0  8.379520e-08 -5.171150e-08   0
#
# [10000 rows x 7 columns]

# %%
plt.figure(figsize=(8,8))
plt.title("Tesz: Föld és Nap", fontsize=28)
plt.plot(data11.X,data11.Y, linestyle='--', color='blue')
plt.plot(data12.X,data12.Y, linestyle='-', color='red')
plt.plot(data11.X[-1:], data11.Y[-1:], marker='.', markersize=24, color='orange')
plt.plot(data12.X[-1:], data12.Y[-1:], marker='.', markersize=16, color='red')
plt.xlabel('X koordináta [AU]', fontsize='22')
plt.ylabel('Y koordináta [AU]', fontsize='22')
plt.grid()
plt.savefig('pics/test1.pdf', format='pdf')
plt.show()

# %%
# Out:
#            T         X        Y  Z        VX       VY  VZ
# 0     0.0000  1.000000  0.00000  0  0.000000  6.00000   0
# 1     0.0001  0.999999  0.00060  0 -0.016752  5.99999   0
# 2     0.0002  0.999997  0.00120  0 -0.033504  5.99993   0
# 3     0.0003  0.999992  0.00180  0 -0.050255  5.99983   0
# 4     0.0004  0.999987  0.00240  0 -0.067005  5.99968   0
# ...      ...       ...      ... ..       ...      ...  ..
# 9995  0.9995 -5.643590  5.61003  0 -6.003060  6.43990   0
# 9996  0.9996 -5.644190  5.61067  0 -6.002990  6.43990   0
# 9997  0.9997 -5.644790  5.61132  0 -6.002920  6.43991   0
# 9998  0.9998 -5.645390  5.61196  0 -6.002850  6.43992   0
# 9999  0.9999 -5.645990  5.61260  0 -6.002780  6.43992   0
#
# [10000 rows x 7 columns]

# %%
colnames=['T','X','Y','Z','VX', 'VY', 'VZ']
colnames_ex = ['T','X','Y','Z','VX', 'VY', 'VZ', 'T', 'U']
file21name = "../.vscode/build/Debug/output/test/body1.csv"
file22name = "../.vscode/build/Debug/output/test/body2.csv"
file23name = "../.vscode/build/Debug/output/test/body3.csv"
data21 = pd.read_csv(file21name,skiprows=1, sep='\t',names=colnames,header=None)
data22 = pd.read_csv(file22name,skiprows=1, sep='\t',names=colnames,header=None)
data23 = pd.read_csv(file23name,skiprows=1, sep='\t',names=colnames,header=None)
data23

plt.figure(figsize=(8,8))
plt.title("Bináris csillagrendszer", fontsize=24)
plt.plot(data21.X,data21.Y, linestyle='-', color='blue', alpha=0.2)
plt.plot(data22.X,data22.Y, linestyle='-', color='green', alpha=0.2)
plt.plot(data23.X,data23.Y, linestyle='-', color='red', alpha=0.8)

plt.plot(data21.X[-1:],data21.Y[-1:], linestyle='--', color='blue', marker='^', markersize=10)
plt.plot(data22.X[-1:],data22.Y[-1:], linestyle='--', color='green',marker='v', markersize=10)
plt.plot(data23.X[-1:],data23.Y[-1:], linestyle='--', color='red',marker='x', markersize=12)

plt.plot(data21.X[0],data21.Y[0], linestyle='--', color='blue', marker='o', markersize=5)
plt.plot(data22.X[0],data22.Y[0], linestyle='--', color='green',marker='o', markersize=5)

plt.xlabel('X koordináta [AU]', fontsize='22')
plt.ylabel('Y koordináta [AU]', fontsize='22')
#plt.xlim(-0.5,0.5)
#plt.ylim(-0.5,0.5)
plt.grid()
plt.tight_layout()
plt.savefig("pics/test2.pdf", format='pdf')
plt.show()

# %%
plt.plot(data21.X,data21.Y, linestyle='--', color='blue')
#plt.plot(data22.X,data22.Y, linestyle='--', color='green')
plt.plot(data21.X[-1:],data21.Y[-1:], linestyle='--', color='blue', marker='o')
#plt.plot(data22.X[-1:],data22.Y[-1:], linestyle='--', color='green',marker='o')
#plt.xlim(-5e-2-1e-17,-5e-2+1e-17)
plt.grid()
plt.show()

# %%
0.9999  0       1
0.9999  0       2
0.9999  0       1
0.9999  0       2
0.9999  0       1
0.9999  0       2
0.9999  0       1
0.9999  0       2
0.9999  1       0
0.9999  1       2
0.9999  1       0
0.9999  1       2
0.9999  1       0
0.9999  1       2
0.9999  1       0
0.9999  1       2
0.9999  2       0
0.9999  2       1
0.9999  2       0
0.9999  2       1
0.9999  2       0
0.9999  2       1
0.9999  2       0
0.9999  2       1
# Out:
#   File "<ipython-input-62-fcbe87549b1d>", line 1
#     0.9999  0       1
#             ^
# SyntaxError: invalid syntax
